# %%
# A simple nerula network

def nerual_network(inputs, weight):
    prediciton=inputs*weight
    return prediction

# %%
# Data 

weight=0.5
inputs=0.5
goal_prediction=0.8

learning_rate=0.001

for iteration in range(1101):
    prediction=inputs*weight
    error=(prediction-goal_prediction)**2
    
    print 'Iteration'+str(iteration)+' Error:'+str(error)+'  Prediction:'+str(prediction)
    
    up_prediction=inputs*(weight+learning_rate)
    up_error=(up_prediction-goal_prediction)**2
    
    down_prediction=inputs*(weight-learning_rate)
    down_error=(down_prediction-goal_prediction)**2
    
    if(down_error<up_error):
        weight-=learning_rate
    else:
        weight+=learning_rate
# Out:
# Iteration0 Error:0.3025  Prediction:0.25
# Iteration1 Error:0.30195025  Prediction:0.2505
# Iteration2 Error:0.301401  Prediction:0.251
# Iteration3 Error:0.30085225  Prediction:0.2515
# Iteration4 Error:0.300304  Prediction:0.252
# Iteration5 Error:0.29975625  Prediction:0.2525
# Iteration6 Error:0.299209  Prediction:0.253
# Iteration7 Error:0.29866225  Prediction:0.2535
# Iteration8 Error:0.298116  Prediction:0.254
# Iteration9 Error:0.29757025  Prediction:0.2545
# Iteration10 Error:0.297025  Prediction:0.255
# Iteration11 Error:0.29648025  Prediction:0.2555
# Iteration12 Error:0.295936  Prediction:0.256
# Iteration13 Error:0.29539225  Prediction:0.2565
# Iteration14 Error:0.294849  Prediction:0.257
# Iteration15 Error:0.29430625  Prediction:0.2575
# Iteration16 Error:0.293764  Prediction:0.258
# Iteration17 Error:0.29322225  Prediction:0.2585
# Iteration18 Error:0.292681  Prediction:0.259
# Iteration19 Error:0.29214025  Prediction:0.2595
# ...
